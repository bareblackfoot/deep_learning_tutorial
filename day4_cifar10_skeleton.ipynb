# %% [markdown]
# # Deep Learning Tutorial <br> Day 4. CIFAR10 Classification
#
# Written by Nuri Kim.
# This code can be downloaded from [GitHub](https://github.com/bareblackfoot/deep_learning_tutorial).
#
# References of this notebook:
# *TensorFlow-Tutorials by [Magnus Erik Hvass Pedersen](http://www.hvass-labs.org/)* and
# *CIFAR-10 by [dhanushkamath](https://github.com/dhanushkamath/CIFAR-10/blob/master/Cifar10.ipynb)*

# %% [markdown]
# ## Introduction
#
# This tutorial demonstrates the workflow of an image classification using TensorFlow with convolutional networks. Unlike MNIST dataset, CIFAR10 dataset has color images of 10 categories. Here, we define and optimize a simple mathematical model in TensorFlow. The results are then plotted.

# %% [markdown]
# ## Imports

# %%
from glob import glob
from time import time
from sklearn.manifold import TSNE
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import confusion_matrix
try:
    from urllib.request import urlretrieve
except:
    from urllib import urlretrieve
import pandas as pd
import numpy as np
import sys, os, math
import tensorflow as tf
import tensorflow.contrib.slim as slim
import matplotlib.pyplot as plt
import itertools
import tarfile
import pickle

print ("Packages loaded")
# Out:
# /usr/local/lib/python3.5/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Packages loaded

# %% [markdown]
# ### Set parameters

# %%
# PARAMS
_BATCH_SIZE = 32
_EPOCH = 10
_SNAPSHOT_PREFIX = "cifar10"
_SAVE_PATH = "./output/cifar10/"
_NUM_VIS_EMBEDDING = 500
if not os.path.exists(_SAVE_PATH):
    os.makedirs(_SAVE_PATH)
_IMAGE_HEIGHT = 32
_IMAGE_WIDTH = 32
_IMAGE_CHANNELS = 3
class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
_NUM_CLASSES = len(class_names)
class_to_num = dict(zip(class_names, range(_NUM_CLASSES)))
num_to_class = dict(zip(range(_NUM_CLASSES), class_names))
lr = 1e-3

# %% [markdown]
# This was developed using Python 3.7 and TensorFlow version 1.10.0. Please check yours:

# %%
tf.__version__
# Out:
# '1.10.1'

# %% [markdown]
# ### Helper-functions for loading images

# %% [markdown]
# Functions used to download dataset and pre-process images.

# %%
def get_data_set(name="train"):
    x = y = None
    maybe_download_and_extract()
    folder_name = "cifar10"
    f = open('./data/'+folder_name+'/batches.meta', 'rb')
    f.close()

    if name is "train":
        for i in range(5):
            f = open('./data/'+folder_name+'/data_batch_' + str(i + 1), 'rb')
            try:
                datadict = pickle.load(f, encoding='latin1') 
            except:
                datadict = pickle.load(f)
            f.close()

            _X = datadict["data"]
            _Y = datadict['labels']

            _X = np.array(_X, dtype=float) / 255.0
            _X = _X.reshape([-1, _IMAGE_CHANNELS, _IMAGE_HEIGHT, _IMAGE_WIDTH])
            _X = _X.transpose([0, 2, 3, 1])
            _X = _X.reshape(-1, _IMAGE_HEIGHT*_IMAGE_WIDTH*_IMAGE_CHANNELS)

            if x is None:
                x = _X
                y = _Y
            else:
                x = np.concatenate((x, _X), axis=0)
                y = np.concatenate((y, _Y), axis=0)

    elif name is "test":
        f = open('./data/'+folder_name+'/test_batch', 'rb')
        try:
            datadict = pickle.load(f, encoding='latin1') 
        except:
            datadict = pickle.load(f)
        f.close()
        x = datadict["data"]
        y = np.array(datadict['labels'])
        x = np.array(x, dtype=float) / 255.0
        x = x.reshape([-1, _IMAGE_CHANNELS, _IMAGE_HEIGHT, _IMAGE_WIDTH])
        x = x.transpose([0, 2, 3, 1])
        x = x.reshape(-1, _IMAGE_HEIGHT*_IMAGE_WIDTH*_IMAGE_CHANNELS)

    return x, dense_to_one_hot(y)

def dense_to_one_hot(labels_dense, num_classes=10):
    num_labels = labels_dense.shape[0]
    index_offset = np.arange(num_labels) * num_classes
    labels_one_hot = np.zeros((num_labels, num_classes))
    labels_one_hot.flat[index_offset + labels_dense.ravel()] = 1
    return labels_one_hot

def print_download_progress(count, block_size, total_size):
    pct_complete = float(count * block_size) / total_size
    msg = "\r- Download progress: {0:.1%}".format(pct_complete)
    sys.stdout.write(msg)
    sys.stdout.flush()
    
def maybe_download_and_extract():
    main_directory = "./data/"
    if not os.path.exists(main_directory):
        os.makedirs(main_directory)
    cifar_10_directory = main_directory+"cifar10/"
    if not os.path.exists(cifar_10_directory):
        url = "http://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz"
        filename = url.split('/')[-1]
        file_path = os.path.join(main_directory, filename)
        zip_cifar_10 = file_path
        file_path, _ = urlretrieve(url=url, filename=file_path, 
                                   reporthook=print_download_progress)

        print()
        print("Download finished. Extracting files.")
        if file_path.endswith(".zip"):
            zipfile.ZipFile(file=file_path, mode="r").extractall(main_directory)
        elif file_path.endswith((".tar.gz", ".tgz")):
            tarfile.open(name=file_path, mode="r:gz").extractall(main_directory)
        print("Done.")

        os.rename(main_directory+"cifar-10-batches-py", cifar_10_directory)
        os.remove(zip_cifar_10)

# %% [markdown]
# ## Load Data
# The size of CIFAR10 dataset is about  180MB and it will be downloaded automatically if it is not located in the given path.

# %%
train_x, train_y = get_data_set("train")
test_x, test_y = get_data_set("test")

print ("Dataset loaded")
# Out:
# Dataset loaded

# %% [markdown]
# The CIFAR10 dataset has now been loaded and consists of 60000 32x32 color images in 10 classes, with 6000 images per class. There are 50000 training images and 10000 test images.

# %% [markdown]
# ### Plot a few images to see if data is correct

# %%
def show_images():
    fig, axes = plt.subplots(3, 3)
    fig.subplots_adjust(hspace=0.6, wspace=0.3)
    
    for i, ax in enumerate(axes.flat):
        # Plot image.
        ax.imshow(train_x[i].reshape(_IMAGE_HEIGHT, _IMAGE_WIDTH, _IMAGE_CHANNELS))
        
        # Name of the true class.
        cls_true_name = num_to_class[train_y[i].argmax()]
        xlabel = "class: {0}".format(cls_true_name)
        
        # Show the classes as the label on the x-axis.
        ax.set_xlabel(xlabel)
        
        # Remove ticks from the plot.
        ax.set_xticks([])
        ax.set_yticks([])
    return

print(train_x.shape)
print(train_y.shape)
show_images()
# Out:
# (50000, 3072)
# (50000, 10)

# %% [markdown]
# ## TensorFlow Graph
#
# The entire purpose of TensorFlow is to have a so-called computational graph that can be executed much more efficiently than if the same calculations were to be performed directly in Python. TensorFlow can be more efficient than NumPy because TensorFlow knows the entire computation graph that must be executed, while NumPy only knows the computation of a single mathematical operation at a time.
#
# TensorFlow can also automatically calculate the gradients that are needed to optimize the variables of the graph so as to make the model perform better. This is because the graph is a combination of simple mathematical expressions so the gradient of the entire graph can be calculated using the chain-rule for derivatives.
#
# TensorFlow can also take advantage of multi-core CPUs as well as GPUs.
#
# A TensorFlow graph consists of the following parts which will be detailed below:
#
# * Placeholder variables used to feed input into the graph.
# * Model variables that are going to be optimized so as to make the model perform better.
# * The model which is essentially just a mathematical function that calculates some output given the input in the placeholder variables and the model variables.
# * A loss measure that can be used to guide the optimization of the variables.
# * An optimization method which updates the variables of the model.
#
# In addition, the TensorFlow graph may also contain various debugging statements e.g. for logging data to be displayed using TensorBoard, which is not covered in this tutorial.

# %% [markdown]
# ### Placeholder variables

# %% [markdown]
# Placeholder variables serve as the input to the graph that we may change each time we execute the graph. We call this feeding the placeholder variables and it is demonstrated further below.
#
# First we define the placeholder variable for the input images. This allows us to change the images that are input to the TensorFlow graph. This is a so-called tensor, which just means that it is a multi-dimensional vector or matrix. The data-type is set to `float32` and the shape is set to `[None, _IMAGE_HEIGHT * _IMAGE_WIDTH * _IMAGE_CHANNEL]`, where `None` means that the tensor may hold an arbitrary number of images with each image being a vector of length `_IMAGE_HEIGHT * _IMAGE_WIDTH * _IMAGE_CHANNEL`.

# %%
x = tf.placeholder(tf.float32, shape=[None, _IMAGE_HEIGHT * _IMAGE_WIDTH * _IMAGE_CHANNELS], name='Input')

# %% [markdown]
# Next we have the placeholder variable for the true labels associated with the images that were input in the placeholder variable `x`. The shape of this placeholder variable is `[None, _NUM_CLASSES]` which means it may hold an arbitrary number of labels and each label is a vector of length `_NUM_CLASSES` which is 10 in this case.

# %%
y_true = tf.placeholder(tf.float32, shape=[None, _NUM_CLASSES], name='Output')

# %% [markdown]
# Since we use a dropout regularization method for a fully connected layer, we have the placeholder variable for the probability to keep variables. If `keep_probability` is 1.0, all variables are the same without the dropout regularization. When `keep_probability` is 0.5, half of the variables in a fully connected layer become 0.0.

# %%
keep_probability = tf.placeholder(tf.float32, shape=[], name='keep_prob')

# %% [markdown]
# `global_step` saves how many optimization iterations are used.

# %%
global_step = tf.Variable(initial_value=0, trainable=False, name='global_step')

# %% [markdown]
# Tensorflow takes an image input in order of `[Batch, _IMAGE_HEIGHT, _IMAGE_WIDTH, _IMAGE_CHANNEL]`. We reshape the input image to make the tensorflow graph can understand the input.

# %%
x_image = tf.reshape(x, [-1, _IMAGE_HEIGHT, _IMAGE_WIDTH, _IMAGE_CHANNELS], name='images')

# %% [markdown]
# ### Network model  to be optimized

# %% [markdown]
# The network consists of `4` convolutional networks and `2` fully connected layers. `conv1_1` layer consists of  filters with weight size `[3, 3, 3, 32]` and bias for each output channel, size `[32]`. `conv1_2` layer consists of filters with weight size `[3, 3, 32, 32]` and bias for each output channel, size `[32]`. `conv2_1` layer contains filters with size `[3, 3, 32, 64]` and bias for each output channel, size `[64]`. `conv2_2` layer consists of filters with size `[3, 3, 64, 64]` and bias for each output channel, size `[64]`. `fully_connected` layer has a filter with weight size `[_IMAGE_HEIGHT/4 * _IMAGE_WIDTH/4 * 64, 1000]`, and bias for each output channel, size 1000. Lastly, the `feat` layer has a filter with weight size `[1000, 10]` and bias for each output channel, size `[10]`.

# %%
### [Task3] Change the network
feat = slim.repeat(x_image, 2, slim.conv2d, 32, [3, 3], scope='conv1')
feat = slim.max_pool2d(feat, [2, 2], padding='SAME', scope='pool1')
feat = slim.repeat(feat, 2, slim.conv2d, 64, [3, 3], scope='conv2')
feat = slim.max_pool2d(feat, [2, 2], padding='SAME', scope='pool2')
feat = slim.flatten(feat, scope='flatten')
feat = slim.fully_connected(feat, 1000, scope='fully_connected')
### [Task2] Change the regularization method
y_pred = slim.fully_connected(feat, _NUM_CLASSES, scope='feat', activation_fn=None)
softmax = tf.nn.softmax(y_pred)
y_pred_cls = tf.argmax(softmax, axis=1)

# %% [markdown]
# Let's see the variables in the network model which we defined above.

# %%
print(tf.global_variables())
# Out:
# [<tf.Variable 'global_step:0' shape=() dtype=int32_ref>, <tf.Variable 'conv1/conv1_1/weights:0' shape=(3, 3, 3, 32) dtype=float32_ref>, <tf.Variable 'conv1/conv1_1/biases:0' shape=(32,) dtype=float32_ref>, <tf.Variable 'conv1/conv1_2/weights:0' shape=(3, 3, 32, 32) dtype=float32_ref>, <tf.Variable 'conv1/conv1_2/biases:0' shape=(32,) dtype=float32_ref>, <tf.Variable 'conv2/conv2_1/weights:0' shape=(3, 3, 32, 64) dtype=float32_ref>, <tf.Variable 'conv2/conv2_1/biases:0' shape=(64,) dtype=float32_ref>, <tf.Variable 'conv2/conv2_2/weights:0' shape=(3, 3, 64, 64) dtype=float32_ref>, <tf.Variable 'conv2/conv2_2/biases:0' shape=(64,) dtype=float32_ref>, <tf.Variable 'fully_connected/weights:0' shape=(4096, 1000) dtype=float32_ref>, <tf.Variable 'fully_connected/biases:0' shape=(1000,) dtype=float32_ref>, <tf.Variable 'feat/weights:0' shape=(1000, 10) dtype=float32_ref>, <tf.Variable 'feat/biases:0' shape=(10,) dtype=float32_ref>]

# %% [markdown]
# ### Loss-function to be optimized

# %% [markdown]
# To make the model better at classifying the input images, we must somehow change the variables for `weights` and `biases`. To do this we first need to know how well the model currently performs by comparing the predicted output of the model `y_pred` to the desired output `y_true`.
#
# The cross-entropy is a performance measure used in classification. The cross-entropy is a continuous function that is always positive and if the predicted output of the model exactly matches the desired output then the cross-entropy equals zero. The goal of optimization is therefore to minimize the cross-entropy so it gets as close to zero as possible by changing the `weights` and `biases` of the model.
#
# TensorFlow has a built-in function for calculating the cross-entropy. Note that it uses the values of the `logits` because it also calculates the softmax internally.

# %%
try:
    cross_entropy = tf.nn.softmax_cross_entropy_with_logits_v2(logits=y_pred, labels=y_true)
except:
    cross_entropy = tf.nn.softmax_cross_entropy_with_logits(logits=y_pred, labels=y_true)

# %% [markdown]
# We have now calculated the cross-entropy for each of the image classifications so we have a measure of how well the model performs on each image individually. But in order to use the cross-entropy to guide the optimization of the model's variables we need a single scalar value, so we simply take the average of the cross-entropy for all the image classifications.

# %%
loss = tf.reduce_mean(cross_entropy)

# %% [markdown]
# ### Optimization method

# %% [markdown]
# Now that we have a loss measure that must be minimized, we can then create an optimizer. In this case it is the basic form of Gradient Descent where the learning rate (step-size) is set to 0.001.
#
# Note that optimization is not performed at this point. In fact, nothing is calculated at all, we just add the optimizer-object to the TensorFlow graph for later execution.

# %%
global_accuracy = 0
epoch_start = 0

### [Task] Write your own optimizer
optimizer =

# %% [markdown]
# ### Performance measures

# %% [markdown]
# We need a few more performance measures to display the progress to the user.
#
# This is a vector of booleans whether the predicted class equals the true class of each image.

# %%
correct_prediction = tf.equal(y_pred_cls, tf.argmax(y_true, axis=1))

# %% [markdown]
# This calculates the classification accuracy by first type-casting the vector of booleans to floats, so that False becomes 0 and True becomes 1, and then calculating the average of these numbers.

# %%
accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))*100.0

# %% [markdown]
# ## TensorFlow Run

# %% [markdown]
# ### Create TensorFlow session
#
# Once the TensorFlow graph has been created, we have to create a TensorFlow session which is used to execute the graph.

# %%
sess = tf.Session()

# %% [markdown]
# A saver which is used for saving the network parameters.

# %%
saver = tf.train.Saver()

# %% [markdown]
# ### Restore or Initialize network parameters

# %% [markdown]
# The variables for `weights` and `biases` in convolutional networks and fully connected layers must be initialized before we start optimizing them. When there is a saved checkpoint, the code restore the paramters in the checkpoint. Otherwise, it just initializes the parameters with random values.

# %%
try:
    last_chk_path = tf.train.latest_checkpoint(checkpoint_dir=_SAVE_PATH)
    saver.restore(sess, save_path=last_chk_path)
    print("Restored checkpoint from:", last_chk_path)
except ValueError:
    sess.run(tf.global_variables_initializer())
    print("Initialized variables.")
# Out:
# Initialized variables.

# %% [markdown]
# ### Helper-functions to plot results

# %% [markdown]
# Function for plotting confusion matrix of test images.

# %%
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    print('Drawing confusion matrix...')
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.show()

# %% [markdown]
# Function for plotting tsne examples of test images.

# %%
def plot_tsne(y_pred_val, y_true_val):
    numbered = LabelEncoder().fit_transform(list(y_true_val))
    c = plt.cm.get_cmap('hsv', len(set(numbered)))
    colors=[]
    for num in numbered:
        temp=c(num)
        colors.append(temp)
        
    print('Fitting TSNE...')
    X_embedded = TSNE(n_components=2).fit_transform(y_pred_val[:10000])
    X_embedded = np.array(X_embedded)
    vis_x = X_embedded[:, 0]
    vis_y = X_embedded[:, 1]
    numbered = LabelEncoder().fit_transform(list(y_true_val))
    c = plt.cm.get_cmap('hsv', len(set(numbered)))
    plt.figure(num=None, figsize=(5, 5), dpi=80, facecolor='w', edgecolor='k')
    plt.scatter(vis_x, vis_y, c=colors,alpha=1,linewidths=1,s=10, edgecolors='none')
    plt.show()
    return X_embedded

# %% [markdown]
# ### Helper-function to test the model at the middle of training

# %%
def test_and_save(_global_step, epoch, y_pred_val, y_true_val):
    global global_accuracy
    global epoch_start

    i = 0
    predicted_class = np.zeros(shape=len(test_x), dtype=np.int)
    while i < len(test_x):
        j = min(i + _BATCH_SIZE, len(test_x))
        batch_xs = test_x[i:j, :]
        batch_ys = test_y[i:j, :]
        predicted_class[i:j] = sess.run(
            y_pred_cls,
            feed_dict={x: batch_xs, y_true: batch_ys, keep_probability: 1.0}
        )    
        i = j
    text_y_argmax = np.argmax(test_y, axis=1)  
    correct = (text_y_argmax == predicted_class)
    acc = correct.mean()*100
    correct_numbers = correct.sum()

    hours, rem = divmod(time() - epoch_start, 3600)
    minutes, seconds = divmod(rem, 60)
    mes = "\nEpoch {} - accuracy: {:.1f}% ({}/{}) - time: {:0>2}:{:0>2}:{:05.2f}"
    print(mes.format((epoch+1), acc, correct_numbers, len(test_x), int(hours), int(minutes), seconds))

    if global_accuracy != 0 and global_accuracy < acc:
        filename = _SNAPSHOT_PREFIX + '_epoch{:d}'.format(epoch) + '.ckpt'
        filename = os.path.join(_SAVE_PATH, filename)
        saver.save(sess, filename)

        mes = "This epoch receive better accuracy: {:.1f}% > {:.1f}%. Saving session..."
        print(mes.format(acc, global_accuracy))
        global_accuracy = acc

    elif global_accuracy == 0:
        global_accuracy = acc
        
    # Plot non-normalized confusion matrix
    cnf_matrix = confusion_matrix(text_y_argmax, predicted_class)
    np.set_printoptions(precision=2)
    plot_confusion_matrix(cnf_matrix, classes=class_names,
                          title='Confusion matrix, without normalization')
    plot_tsne(y_pred_val, y_true_val)
    
    print("###########################################################################################################")

# %% [markdown]
# ### Helper-function to perform optimization iterations

# %% [markdown]
# Function for performing a number of optimization iterations so as to gradually improve the `weights` and `biases` of the model. In each iteration, a new batch of data is selected from the training-set and then TensorFlow executes the optimizer using those training samples.

# %%
def train(epoch):
    global epoch_start
    epoch_start = time()
    batch_size = int(math.ceil(len(train_x) / _BATCH_SIZE))
    i_global = 0

    for s in range(batch_size):
        batch_xs = train_x[s*_BATCH_SIZE: (s+1)*_BATCH_SIZE]
        batch_ys = train_y[s*_BATCH_SIZE: (s+1)*_BATCH_SIZE]

        start_time = time()
        i_global, _, batch_loss, batch_acc = sess.run(
            [global_step, optimizer, loss, accuracy],
            feed_dict={x: batch_xs, y_true: batch_ys, keep_probability: 0.5})
        duration = time() - start_time

        if s % 100 == 0:
            percentage = int(float(s)/float(batch_size)*100.0)
            bar_len = 29
            filled_len = int((bar_len*int(percentage))/100)
            bar = '=' * filled_len + '>' + '-' * (bar_len - filled_len)

            msg = "Global step: {:>5} - [{}] {:>3}% - accuracy: {:.1f}% - loss: {:.4f} - {:.1f} sample/sec"
            print(msg.format(i_global, bar, percentage, batch_acc, batch_loss, _BATCH_SIZE / duration))
    y_pred_val = sess.run(y_pred, feed_dict={x: train_x[:_NUM_VIS_EMBEDDING], keep_probability: 1.0})
    y_true_val = train_y[:_NUM_VIS_EMBEDDING]
    y_true_val = y_true_val.argmax(1)

    test_and_save(i_global, epoch, y_pred_val, y_true_val)

# %% [markdown]
# ### Start training networks

# %% [markdown]
# Weights are optimized and the accuracy on the test set increases as global step increases.

# %%
print("Start training")
train_start = time()

for i in range(_EPOCH):
    print("\nEpoch: {}/{}\n".format((i+1), _EPOCH))
    train(i)

hours, rem = divmod(time() - train_start, 3600)
minutes, seconds = divmod(rem, 60)
mes = "Best accuracy pre session: {:.2f}, time: {:0>2}:{:0>2}:{:05.2f}"
print(mes.format(global_accuracy, int(hours), int(minutes), seconds))
print("Done training")
# Out:
# Start training
#
# Epoch: 1/10
#
# Global step:     1 - [>-----------------------------]   0% - accuracy: 6.2% - loss: 2.3489 - 50.6 sample/sec
# Global step:   101 - [=>----------------------------]   6% - accuracy: 34.4% - loss: 2.0342 - 7201.3 sample/sec
# Global step:   201 - [===>--------------------------]  12% - accuracy: 43.8% - loss: 1.6152 - 7306.4 sample/sec
# Global step:   301 - [=====>------------------------]  19% - accuracy: 50.0% - loss: 1.6612 - 7282.2 sample/sec
# Global step:   401 - [=======>----------------------]  25% - accuracy: 37.5% - loss: 1.4118 - 5150.7 sample/sec
# Global step:   501 - [========>---------------------]  31% - accuracy: 59.4% - loss: 1.2627 - 2708.7 sample/sec
# Global step:   601 - [===========>------------------]  38% - accuracy: 62.5% - loss: 1.1135 - 7410.0 sample/sec
# Global step:   701 - [============>-----------------]  44% - accuracy: 34.4% - loss: 1.4991 - 7397.4 sample/sec
# Global step:   801 - [==============>---------------]  51% - accuracy: 53.1% - loss: 1.1548 - 7267.6 sample/sec
# Global step:   901 - [================>-------------]  57% - accuracy: 59.4% - loss: 1.0967 - 7353.6 sample/sec
# Global step:  1001 - [==================>-----------]  63% - accuracy: 56.2% - loss: 1.1362 - 7267.2 sample/sec
# Global step:  1101 - [====================>---------]  70% - accuracy: 46.9% - loss: 1.2842 - 4267.5 sample/sec
# Global step:  1201 - [======================>-------]  76% - accuracy: 56.2% - loss: 1.1382 - 7144.6 sample/sec
# Global step:  1301 - [========================>-----]  83% - accuracy: 56.2% - loss: 1.0193 - 7176.7 sample/sec
# Global step:  1401 - [=========================>----]  89% - accuracy: 68.8% - loss: 1.0164 - 7379.9 sample/sec
# Global step:  1501 - [===========================>--]  95% - accuracy: 43.8% - loss: 1.5784 - 6490.5 sample/sec
#
# Epoch 1 - accuracy: 66.6% (6665/10000) - time: 00:00:08.54
# Drawing confusion matrix...
# Confusion matrix, without normalization
# Fitting TSNE...
# ###########################################################################################################
#
# Epoch: 2/10
#
# Global step:  1564 - [>-----------------------------]   0% - accuracy: 65.6% - loss: 0.8764 - 2519.6 sample/sec
# Global step:  1664 - [=>----------------------------]   6% - accuracy: 56.2% - loss: 1.0763 - 7355.6 sample/sec
# Global step:  1764 - [===>--------------------------]  12% - accuracy: 62.5% - loss: 0.8935 - 7324.3 sample/sec
# Global step:  1864 - [=====>------------------------]  19% - accuracy: 62.5% - loss: 1.0435 - 6995.2 sample/sec
# Global step:  1964 - [=======>----------------------]  25% - accuracy: 68.8% - loss: 0.9580 - 7203.6 sample/sec
# Global step:  2064 - [========>---------------------]  31% - accuracy: 68.8% - loss: 0.8969 - 7043.3 sample/sec
# Global step:  2164 - [===========>------------------]  38% - accuracy: 78.1% - loss: 0.8350 - 7327.5 sample/sec
# Global step:  2264 - [============>-----------------]  44% - accuracy: 50.0% - loss: 1.0868 - 7322.7 sample/sec
# Global step:  2364 - [==============>---------------]  51% - accuracy: 75.0% - loss: 0.8048 - 7226.9 sample/sec
# Global step:  2464 - [================>-------------]  57% - accuracy: 71.9% - loss: 0.8425 - 6778.7 sample/sec
# Global step:  2564 - [==================>-----------]  63% - accuracy: 71.9% - loss: 0.7935 - 7155.2 sample/sec
# Global step:  2664 - [====================>---------]  70% - accuracy: 71.9% - loss: 0.7817 - 7157.1 sample/sec
# Global step:  2764 - [======================>-------]  76% - accuracy: 81.2% - loss: 0.5897 - 7174.7 sample/sec
# Global step:  2864 - [========================>-----]  83% - accuracy: 62.5% - loss: 0.9809 - 6907.4 sample/sec
# Global step:  2964 - [=========================>----]  89% - accuracy: 68.8% - loss: 1.0522 - 7344.7 sample/sec
# Global step:  3064 - [===========================>--]  95% - accuracy: 53.1% - loss: 1.2414 - 7317.9 sample/sec
#
# Epoch 2 - accuracy: 71.5% (7147/10000) - time: 00:00:07.62
# This epoch receive better accuracy: 71.5% > 66.6%. Saving session...
# Drawing confusion matrix...
# Confusion matrix, without normalization
# Fitting TSNE...
# ###########################################################################################################
#
# Epoch: 3/10
#
# Global step:  3127 - [>-----------------------------]   0% - accuracy: 87.5% - loss: 0.4935 - 5400.2 sample/sec
# Global step:  3227 - [=>----------------------------]   6% - accuracy: 71.9% - loss: 0.6906 - 4677.7 sample/sec
# Global step:  3327 - [===>--------------------------]  12% - accuracy: 62.5% - loss: 0.9313 - 7149.9 sample/sec
# Global step:  3427 - [=====>------------------------]  19% - accuracy: 78.1% - loss: 0.7207 - 7192.8 sample/sec
# Global step:  3527 - [=======>----------------------]  25% - accuracy: 75.0% - loss: 0.6212 - 7155.6 sample/sec
# Global step:  3627 - [========>---------------------]  31% - accuracy: 78.1% - loss: 0.6978 - 7226.1 sample/sec
# Global step:  3727 - [===========>------------------]  38% - accuracy: 78.1% - loss: 0.7008 - 7270.7 sample/sec
# Global step:  3827 - [============>-----------------]  44% - accuracy: 65.6% - loss: 0.9504 - 7239.8 sample/sec
# Global step:  3927 - [==============>---------------]  51% - accuracy: 87.5% - loss: 0.5068 - 7333.5 sample/sec
# Global step:  4027 - [================>-------------]  57% - accuracy: 87.5% - loss: 0.4898 - 7080.9 sample/sec
# Global step:  4127 - [==================>-----------]  63% - accuracy: 75.0% - loss: 0.7704 - 6832.5 sample/sec
# Global step:  4227 - [====================>---------]  70% - accuracy: 78.1% - loss: 0.5755 - 7196.7 sample/sec
# Global step:  4327 - [======================>-------]  76% - accuracy: 84.4% - loss: 0.4028 - 7229.6 sample/sec
# Global step:  4427 - [========================>-----]  83% - accuracy: 75.0% - loss: 0.8460 - 5443.8 sample/sec
# Global step:  4527 - [=========================>----]  89% - accuracy: 71.9% - loss: 0.7241 - 7263.3 sample/sec
# Global step:  4627 - [===========================>--]  95% - accuracy: 59.4% - loss: 1.1965 - 7195.5 sample/sec
#
# Epoch 3 - accuracy: 72.4% (7241/10000) - time: 00:00:07.90
# This epoch receive better accuracy: 72.4% > 71.5%. Saving session...
# Drawing confusion matrix...
# Confusion matrix, without normalization
# Fitting TSNE...
# ###########################################################################################################
#
# Epoch: 4/10
#
# Global step:  4690 - [>-----------------------------]   0% - accuracy: 90.6% - loss: 0.3554 - 3193.8 sample/sec
# Global step:  4790 - [=>----------------------------]   6% - accuracy: 75.0% - loss: 0.6079 - 7144.2 sample/sec
# Global step:  4890 - [===>--------------------------]  12% - accuracy: 71.9% - loss: 0.6688 - 7154.1 sample/sec
# Global step:  4990 - [=====>------------------------]  19% - accuracy: 71.9% - loss: 0.6373 - 7428.1 sample/sec
# Global step:  5090 - [=======>----------------------]  25% - accuracy: 78.1% - loss: 0.4763 - 7205.9 sample/sec
# Global step:  5190 - [========>---------------------]  31% - accuracy: 87.5% - loss: 0.4673 - 7216.8 sample/sec
# Global step:  5290 - [===========>------------------]  38% - accuracy: 71.9% - loss: 0.7897 - 7219.9 sample/sec
# Global step:  5390 - [============>-----------------]  44% - accuracy: 68.8% - loss: 0.6820 - 7348.8 sample/sec
# Global step:  5490 - [==============>---------------]  51% - accuracy: 87.5% - loss: 0.4182 - 7294.4 sample/sec
# Global step:  5590 - [================>-------------]  57% - accuracy: 81.2% - loss: 0.4366 - 7270.7 sample/sec
# Global step:  5690 - [==================>-----------]  63% - accuracy: 81.2% - loss: 0.6164 - 7279.0 sample/sec
# Global step:  5790 - [====================>---------]  70% - accuracy: 78.1% - loss: 0.4673 - 7118.0 sample/sec
# Global step:  5890 - [======================>-------]  76% - accuracy: 84.4% - loss: 0.4576 - 7268.4 sample/sec
# Global step:  5990 - [========================>-----]  83% - accuracy: 81.2% - loss: 0.6242 - 7183.9 sample/sec
# Global step:  6090 - [=========================>----]  89% - accuracy: 78.1% - loss: 0.6229 - 7331.9 sample/sec
# Global step:  6190 - [===========================>--]  95% - accuracy: 75.0% - loss: 0.7869 - 7290.1 sample/sec
#
# Epoch 4 - accuracy: 74.1% (7407/10000) - time: 00:00:07.58
# This epoch receive better accuracy: 74.1% > 72.4%. Saving session...
# Drawing confusion matrix...
# Confusion matrix, without normalization
# Fitting TSNE...
# ###########################################################################################################
#
# Epoch: 5/10
#
# Global step:  6253 - [>-----------------------------]   0% - accuracy: 96.9% - loss: 0.2607 - 2137.0 sample/sec
# Global step:  6353 - [=>----------------------------]   6% - accuracy: 90.6% - loss: 0.4012 - 7225.3 sample/sec
# Global step:  6453 - [===>--------------------------]  12% - accuracy: 65.6% - loss: 0.7042 - 7428.5 sample/sec
# Global step:  6553 - [=====>------------------------]  19% - accuracy: 78.1% - loss: 0.4122 - 7179.3 sample/sec
# Global step:  6653 - [=======>----------------------]  25% - accuracy: 93.8% - loss: 0.3639 - 7145.7 sample/sec
# Global step:  6753 - [========>---------------------]  31% - accuracy: 81.2% - loss: 0.4923 - 7408.4 sample/sec
# Global step:  6853 - [===========>------------------]  38% - accuracy: 71.9% - loss: 0.7725 - 7302.4 sample/sec
# Global step:  6953 - [============>-----------------]  44% - accuracy: 71.9% - loss: 0.7812 - 7216.8 sample/sec
# Global step:  7053 - [==============>---------------]  51% - accuracy: 78.1% - loss: 0.3917 - 7122.9 sample/sec
# Global step:  7153 - [================>-------------]  57% - accuracy: 81.2% - loss: 0.5031 - 7232.3 sample/sec
# Global step:  7253 - [==================>-----------]  63% - accuracy: 84.4% - loss: 0.4755 - 7214.5 sample/sec
# Global step:  7353 - [====================>---------]  70% - accuracy: 81.2% - loss: 0.5108 - 6262.8 sample/sec
# Global step:  7453 - [======================>-------]  76% - accuracy: 90.6% - loss: 0.3294 - 7319.1 sample/sec
# Global step:  7553 - [========================>-----]  83% - accuracy: 78.1% - loss: 0.5448 - 7215.6 sample/sec
# Global step:  7653 - [=========================>----]  89% - accuracy: 78.1% - loss: 0.8425 - 7320.3 sample/sec
# Global step:  7753 - [===========================>--]  95% - accuracy: 65.6% - loss: 0.9559 - 7209.4 sample/sec
#
# Epoch 5 - accuracy: 74.2% (7419/10000) - time: 00:00:07.54
# This epoch receive better accuracy: 74.2% > 74.1%. Saving session...
# Drawing confusion matrix...
# Confusion matrix, without normalization
# Fitting TSNE...
# ###########################################################################################################
#
# Epoch: 6/10
#
# Global step:  7816 - [>-----------------------------]   0% - accuracy: 96.9% - loss: 0.2776 - 2790.9 sample/sec
# Global step:  7916 - [=>----------------------------]   6% - accuracy: 84.4% - loss: 0.3736 - 7205.9 sample/sec
# Global step:  8016 - [===>--------------------------]  12% - accuracy: 84.4% - loss: 0.4099 - 7355.2 sample/sec
# Global step:  8116 - [=====>------------------------]  19% - accuracy: 90.6% - loss: 0.3447 - 7354.0 sample/sec
# Global step:  8216 - [=======>----------------------]  25% - accuracy: 84.4% - loss: 0.4203 - 7040.7 sample/sec
# Global step:  8316 - [========>---------------------]  31% - accuracy: 87.5% - loss: 0.2144 - 7274.7 sample/sec
# Global step:  8416 - [===========>------------------]  38% - accuracy: 75.0% - loss: 0.6342 - 6674.8 sample/sec
# Global step:  8516 - [============>-----------------]  44% - accuracy: 84.4% - loss: 0.6016 - 7297.6 sample/sec
# Global step:  8616 - [==============>---------------]  51% - accuracy: 84.4% - loss: 0.3755 - 7231.9 sample/sec
# Global step:  8716 - [================>-------------]  57% - accuracy: 90.6% - loss: 0.2781 - 7274.3 sample/sec
# Global step:  8816 - [==================>-----------]  63% - accuracy: 93.8% - loss: 0.2944 - 7257.8 sample/sec
# Global step:  8916 - [====================>---------]  70% - accuracy: 93.8% - loss: 0.2697 - 7281.0 sample/sec
# Global step:  9016 - [======================>-------]  76% - accuracy: 93.8% - loss: 0.1790 - 7244.4 sample/sec
# Global step:  9116 - [========================>-----]  83% - accuracy: 93.8% - loss: 0.2428 - 7284.5 sample/sec
# Global step:  9216 - [=========================>----]  89% - accuracy: 93.8% - loss: 0.3022 - 7186.6 sample/sec
# Global step:  9316 - [===========================>--]  95% - accuracy: 90.6% - loss: 0.4932 - 7345.9 sample/sec
#
# Epoch 6 - accuracy: 74.7% (7473/10000) - time: 00:00:07.55
# This epoch receive better accuracy: 74.7% > 74.2%. Saving session...
# Drawing confusion matrix...
# Confusion matrix, without normalization
# Fitting TSNE...
# ###########################################################################################################
#
# Epoch: 7/10
#
# Global step:  9379 - [>-----------------------------]   0% - accuracy: 93.8% - loss: 0.2227 - 5093.7 sample/sec
# Global step:  9479 - [=>----------------------------]   6% - accuracy: 87.5% - loss: 0.2384 - 7122.6 sample/sec
# Global step:  9579 - [===>--------------------------]  12% - accuracy: 81.2% - loss: 0.5393 - 7133.2 sample/sec
# Global step:  9679 - [=====>------------------------]  19% - accuracy: 93.8% - loss: 0.2501 - 7277.8 sample/sec
# Global step:  9779 - [=======>----------------------]  25% - accuracy: 87.5% - loss: 0.2933 - 7228.4 sample/sec
# Global step:  9879 - [========>---------------------]  31% - accuracy: 93.8% - loss: 0.1475 - 7282.2 sample/sec
# Global step:  9979 - [===========>------------------]  38% - accuracy: 90.6% - loss: 0.2815 - 7205.2 sample/sec
# Global step: 10079 - [============>-----------------]  44% - accuracy: 84.4% - loss: 0.3582 - 7216.8 sample/sec
# Global step: 10179 - [==============>---------------]  51% - accuracy: 100.0% - loss: 0.1247 - 7343.9 sample/sec
# Global step: 10279 - [================>-------------]  57% - accuracy: 90.6% - loss: 0.4323 - 7200.9 sample/sec
# Global step: 10379 - [==================>-----------]  63% - accuracy: 93.8% - loss: 0.2846 - 7278.6 sample/sec
# Global step: 10479 - [====================>---------]  70% - accuracy: 90.6% - loss: 0.2825 - 7309.5 sample/sec
# Global step: 10579 - [======================>-------]  76% - accuracy: 87.5% - loss: 0.3003 - 7284.9 sample/sec
# Global step: 10679 - [========================>-----]  83% - accuracy: 87.5% - loss: 0.4247 - 7206.3 sample/sec
# Global step: 10779 - [=========================>----]  89% - accuracy: 87.5% - loss: 0.3457 - 7335.1 sample/sec
# Global step: 10879 - [===========================>--]  95% - accuracy: 87.5% - loss: 0.4767 - 7136.2 sample/sec
#
# Epoch 7 - accuracy: 74.0% (7396/10000) - time: 00:00:07.55
# Drawing confusion matrix...
# Confusion matrix, without normalization
# Fitting TSNE...
# ###########################################################################################################
#
# Epoch: 8/10
#
# Global step: 10942 - [>-----------------------------]   0% - accuracy: 87.5% - loss: 0.2448 - 5230.8 sample/sec
# Global step: 11042 - [=>----------------------------]   6% - accuracy: 84.4% - loss: 0.2112 - 7311.1 sample/sec
# Global step: 11142 - [===>--------------------------]  12% - accuracy: 87.5% - loss: 0.3250 - 7112.8 sample/sec
# Global step: 11242 - [=====>------------------------]  19% - accuracy: 90.6% - loss: 0.2444 - 7264.8 sample/sec
# Global step: 11342 - [=======>----------------------]  25% - accuracy: 90.6% - loss: 0.2165 - 7356.8 sample/sec
# Global step: 11442 - [========>---------------------]  31% - accuracy: 87.5% - loss: 0.3701 - 7265.6 sample/sec
# Global step: 11542 - [===========>------------------]  38% - accuracy: 84.4% - loss: 0.5030 - 7379.9 sample/sec
# Global step: 11642 - [============>-----------------]  44% - accuracy: 84.4% - loss: 0.2933 - 7437.5 sample/sec
# Global step: 11742 - [==============>---------------]  51% - accuracy: 87.5% - loss: 0.2350 - 6466.8 sample/sec
# Global step: 11842 - [================>-------------]  57% - accuracy: 84.4% - loss: 0.5182 - 7276.3 sample/sec
# Global step: 11942 - [==================>-----------]  63% - accuracy: 96.9% - loss: 0.0768 - 7381.5 sample/sec
# Global step: 12042 - [====================>---------]  70% - accuracy: 93.8% - loss: 0.2894 - 7291.3 sample/sec
# Global step: 12142 - [======================>-------]  76% - accuracy: 96.9% - loss: 0.0808 - 7160.6 sample/sec
# Global step: 12242 - [========================>-----]  83% - accuracy: 96.9% - loss: 0.1640 - 7232.3 sample/sec
# Global step: 12342 - [=========================>----]  89% - accuracy: 93.8% - loss: 0.2647 - 7375.0 sample/sec
# Global step: 12442 - [===========================>--]  95% - accuracy: 90.6% - loss: 0.3018 - 7490.7 sample/sec
#
# Epoch 8 - accuracy: 75.4% (7541/10000) - time: 00:00:07.44
# This epoch receive better accuracy: 75.4% > 74.7%. Saving session...
# Drawing confusion matrix...
# Confusion matrix, without normalization
# Fitting TSNE...
# ###########################################################################################################
#
# Epoch: 9/10
#
# Global step: 12505 - [>-----------------------------]   0% - accuracy: 96.9% - loss: 0.1137 - 5510.2 sample/sec
# Global step: 12605 - [=>----------------------------]   6% - accuracy: 87.5% - loss: 0.2269 - 7222.6 sample/sec
# Global step: 12705 - [===>--------------------------]  12% - accuracy: 87.5% - loss: 0.3663 - 7420.7 sample/sec
# Global step: 12805 - [=====>------------------------]  19% - accuracy: 100.0% - loss: 0.0948 - 7361.7 sample/sec
# Global step: 12905 - [=======>----------------------]  25% - accuracy: 96.9% - loss: 0.1355 - 7080.1 sample/sec
# Global step: 13005 - [========>---------------------]  31% - accuracy: 96.9% - loss: 0.1593 - 7516.3 sample/sec
# Global step: 13105 - [===========>------------------]  38% - accuracy: 96.9% - loss: 0.1732 - 7318.7 sample/sec
# Global step: 13205 - [============>-----------------]  44% - accuracy: 84.4% - loss: 0.2756 - 6231.7 sample/sec
# Global step: 13305 - [==============>---------------]  51% - accuracy: 93.8% - loss: 0.1817 - 7060.4 sample/sec
# Global step: 13405 - [================>-------------]  57% - accuracy: 96.9% - loss: 0.0955 - 7077.5 sample/sec
# Global step: 13505 - [==================>-----------]  63% - accuracy: 96.9% - loss: 0.1300 - 7138.9 sample/sec
# Global step: 13605 - [====================>---------]  70% - accuracy: 87.5% - loss: 0.2613 - 7309.1 sample/sec
# Global step: 13705 - [======================>-------]  76% - accuracy: 90.6% - loss: 0.3064 - 7317.1 sample/sec
# Global step: 13805 - [========================>-----]  83% - accuracy: 96.9% - loss: 0.1135 - 7409.2 sample/sec
# Global step: 13905 - [=========================>----]  89% - accuracy: 96.9% - loss: 0.1421 - 7323.1 sample/sec
# Global step: 14005 - [===========================>--]  95% - accuracy: 81.2% - loss: 0.5225 - 7433.4 sample/sec
#
# Epoch 9 - accuracy: 74.2% (7420/10000) - time: 00:00:07.47
# Drawing confusion matrix...
# Confusion matrix, without normalization
# Fitting TSNE...
# ###########################################################################################################
#
# Epoch: 10/10
#
# Global step: 14068 - [>-----------------------------]   0% - accuracy: 100.0% - loss: 0.0213 - 2135.0 sample/sec
# Global step: 14168 - [=>----------------------------]   6% - accuracy: 87.5% - loss: 0.1822 - 7352.0 sample/sec
# Global step: 14268 - [===>--------------------------]  12% - accuracy: 87.5% - loss: 0.2371 - 7342.3 sample/sec
# Global step: 14368 - [=====>------------------------]  19% - accuracy: 87.5% - loss: 0.4685 - 7440.8 sample/sec
# Global step: 14468 - [=======>----------------------]  25% - accuracy: 93.8% - loss: 0.2513 - 7409.2 sample/sec
# Global step: 14568 - [========>---------------------]  31% - accuracy: 87.5% - loss: 0.2831 - 7101.5 sample/sec
# Global step: 14668 - [===========>------------------]  38% - accuracy: 93.8% - loss: 0.1968 - 7341.5 sample/sec
# Global step: 14768 - [============>-----------------]  44% - accuracy: 87.5% - loss: 0.3300 - 7431.8 sample/sec
# Global step: 14868 - [==============>---------------]  51% - accuracy: 87.5% - loss: 0.2695 - 7339.5 sample/sec
# Global step: 14968 - [================>-------------]  57% - accuracy: 96.9% - loss: 0.1467 - 7353.2 sample/sec
# Global step: 15068 - [==================>-----------]  63% - accuracy: 87.5% - loss: 0.2209 - 7324.7 sample/sec
# Global step: 15168 - [====================>---------]  70% - accuracy: 93.8% - loss: 0.2544 - 7193.2 sample/sec
# Global step: 15268 - [======================>-------]  76% - accuracy: 93.8% - loss: 0.2417 - 7376.2 sample/sec
# Global step: 15368 - [========================>-----]  83% - accuracy: 96.9% - loss: 0.1313 - 7213.7 sample/sec
# Global step: 15468 - [=========================>----]  89% - accuracy: 93.8% - loss: 0.1544 - 7458.2 sample/sec
# Global step: 15568 - [===========================>--]  95% - accuracy: 90.6% - loss: 0.2917 - 7317.9 sample/sec
#
# Epoch 10 - accuracy: 74.7% (7470/10000) - time: 00:00:07.45
# Drawing confusion matrix...
# Confusion matrix, without normalization
# Fitting TSNE...
# ###########################################################################################################
# Best accuracy pre session: 75.41, time: 00:02:23.61
# Done training
